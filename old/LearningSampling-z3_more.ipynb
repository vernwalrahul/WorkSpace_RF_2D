# %%
#Pre-Processing

import os
import argparse
import networkx as nx
import math        
import numpy as np

def state_to_numpy(state):
    strlist = state.split()
    val_list = [float(s) for s in strlist]
    return np.array(val_list)

def list_all_dir(data_dir):
    task_dirs = os.listdir(data_dir)

    list_dir = []
    for task_dir in task_dirs:
        env_dirs = os.listdir(data_dir+"/"+task_dir)
        for env_dir in env_dirs:
            list_dir.append(data_dir +"/"+ task_dir +"/"+ env_dir)
    return list_dir  

def process_it(G, directory):
    start = np.loadtxt(directory+"/start_nodes.txt")
    goal = np.loadtxt(directory+"/goal_nodes.txt")
    occ_grid = np.loadtxt(directory+"/occ_grid.txt")
    # occ_grid = occ_grid.split(",")
    path_nodes = []
    i = 0
    all_data = []
    with open(directory + "/path_nodes.txt", 'r') as file:
        lines  = file.readlines()
        for line in lines:
            line = line.strip('\n')
#             print(line)
#             print("\n\n")
            
            s = state_to_numpy(G.node[str(int(start[i]))]['state'])
            g = state_to_numpy(G.node[str(int(goal[i]))]['state'])
            og = occ_grid[i]
            path_nodes = str(line).split(",")
            # print(path_nodes)
            for path_node in path_nodes:
                if(path_node=='-1'):
                    continue
                node_conf = state_to_numpy(G.node[path_node]['state'])
                curr_node = np.array([])
                # print("Data = ",node_conf, s, g, occ_grid)
#                     print("\n")
#                     print("node_conf = ", node_conf, " s = ", s, " g = ",g)

                curr_node = np.concatenate((node_conf, s, g, og))
#                     print("shape of curr_node = ", curr_node.shape)
                all_data.append(curr_node)
            i+=1
    return all_data

# %%
# Workspace problem with several narrow gaps

import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import matplotlib.gridspec as gridspec
from mpl_toolkits.mplot3d import Axes3D
import os
import csv
from random import randint, random
import time

# (restrict tensorflow memory growth)
os.environ["CUDA_VISIBLE_DEVICES"]="1"
config = tf.ConfigProto()
config.gpu_options.allow_growth=True

# %%
# neural network parameters
mb_size = 256
h_Q_dim = 512
h_P_dim = 512

c = 0
# learning rate
lr = 1e-4

# problem dimensions
dim = 2
dataElements = dim*3 + 400 # sample (7D), init (7D), goal (7D), cond (occ_grid) //total = 206

z_dim = 1 # latent
X_dim = dim # samples
y_dim = dim # reconstruction of the original point
c_dim = dataElements - dim # dimension of conditioning variable

# %%
G = nx.read_graphml("graphs_2d/dense_graph.graphml")
data_dir = "dataset_new"

directory = data_dir
print(directory)
final_data = []
flag = 0

data = np.array(process_it(G, directory))
np.random.shuffle(data)
print("shape of array: ",data.shape)

numEntries = data.shape[0]

# %%
print("data.shape = ", data.shape)
# Out:
# ('data.shape = ', (10045, 406))

# %%
# split the inputs and conditions into test train (to be processed in the next step into an occupancy grid representation)
ratioTestTrain = 0.2;
numTrain = int(numEntries*ratioTestTrain)

X_train = data[0:numTrain,0:dim] # state: x, y, z, xdot, ydot, zdot
c_train = data[0:numTrain,dim:dataElements] # conditions: gaps, init (6), goal (6)

X_test = data[numTrain:numEntries,0:dim]
c_test = data[numTrain:numEntries,dim:dataElements]

#########################################################
c_train1 = []
c_test1 = []
c_train1 = c_train
c_test1 = c_test
#########################################################
numTest = X_test.shape[0]
# print(data[:,:6])
# print(c_test[:,:4])

# print("shape of final obstacle = ",obs.shape)
print("shape of c_train1 = ", c_train1.shape)
print("shape of c_test1 = ",c_test1.shape)
# Out:
# ('shape of c_train1 = ', (2009, 404))
# ('shape of c_test1 = ', (8036, 404))

# %%
# define networks
print("X_dim = ",X_dim)
print("c_dim = ",c_dim)
X = tf.placeholder(tf.float32, shape=[None, X_dim])
c = tf.placeholder(tf.float32, shape=[None, c_dim])
    
# Q
inputs_Q = tf.concat(axis=1, values=[X,c])

dense_Q1 = tf.layers.dense(inputs=inputs_Q, units=h_Q_dim, activation=tf.nn.relu)
dropout_Q1 = tf.layers.dropout(inputs=dense_Q1, rate=0.5)
dense_Q2 = tf.layers.dense(inputs=dropout_Q1, units=h_Q_dim, activation=tf.nn.relu)

z_mu = tf.layers.dense(inputs=dense_Q2, units=z_dim) # output here is z_mu
z_logvar = tf.layers.dense(inputs=dense_Q2, units=z_dim) # output here is z_logvar

# P
eps = tf.random_normal(shape=tf.shape(z_mu))
z = z_mu + tf.exp(z_logvar / 2) * eps
inputs_P = tf.concat(axis=1, values=[z,c])

dense_P1 = tf.layers.dense(inputs=inputs_P, units=h_P_dim, activation=tf.nn.relu)
dropout_P1 = tf.layers.dropout(inputs=dense_P1, rate=0.5)
dense_P2 = tf.layers.dense(inputs=dropout_P1, units=h_P_dim, activation=tf.nn.relu)

y = tf.layers.dense(inputs=dense_P2, units=X_dim) # fix to also output y

# training
########### comment in the one with 0 weight and uncomment the other ###########
w = [[1, 1]];
# w = [[1, 1, 1, 0, 0, 0]];
recon_loss = tf.losses.mean_squared_error(labels=X, predictions=y, weights=w)

# TODO: fix loss function for angles going around
kl_loss = 10**-4 * 2 * tf.reduce_sum(tf.exp(z_logvar) + z_mu**2 - 1. - z_logvar, 1)

cvae_loss = tf.reduce_mean(kl_loss + recon_loss)

train_step = tf.train.AdamOptimizer(lr).minimize(cvae_loss)

sess = tf.Session(config=config)
sess.run(tf.global_variables_initializer())
it = 0;
# Out:
# ('X_dim = ', 2)
# ('c_dim = ', 404)

# %%
saver = tf.train.Saver()
path_ = os.getcwd() + "/checkpoints_z3_1l_more/model.ckpt"
print("path = ",path_)
print("numTrain = ",numTrain)
try:
    saver.restore(sess, path_)
    print("Model Restored!!")
except Exception as e:
    print("Could not restore checkpoint!")
    print(e)
x1 = []
y1 = []    
print("z_dim = ", z_dim)
print("c_dim = ", c_dim)
print("c_train = ", c_train.shape)
for it in range(it,it+600001):
#     print("c_dim = ",c_dim)
    # randomly generate batches
    batch_elements = [randint(0,numTrain-1) for n in range(0,mb_size)]
    X_mb = X_train[batch_elements,:]
    c_mb = c_train1[batch_elements,:]

    _, loss, r = sess.run([train_step, cvae_loss, recon_loss], feed_dict={X: X_mb, c: c_mb})

    if it % 1000 == 0:
        print('Iter: {}'.format(it))
        print('Loss: {:.4}'. format(loss))
        x1.append(it)
        y1.append(loss)
        print("recon_loss = ", r)
    if it % 1000 == 0:    
        saver.save(sess, path_)
        print("saved session to ", path_)
# Out:
# ('path = ', '/home/vernwalrahul/projects/Workspace_halton_2d/checkpoints_z3_1l_more/model.ckpt')
# ('numTrain = ', 2009)
# INFO:tensorflow:Restoring parameters from /home/vernwalrahul/projects/Workspace_halton_2d/checkpoints_z3_1l_more/model.ckpt
# Could not restore checkpoint!
# Key beta1_power_15 not found in checkpoint
# 	 [[Node: save_8/RestoreV2_7 = RestoreV2[dtypes=[DT_FLOAT], _device="/job:localhost/replica:0/task:0/cpu:0"](_arg_save_8/Const_0_0, save_8/RestoreV2_7/tensor_names, save_8/RestoreV2_7/shape_and_slices)]]
#
# Caused by op u'save_8/RestoreV2_7', defined at:
#   File "/usr/lib/python2.7/runpy.py", line 174, in _run_module_as_main
#     "__main__", fname, loader, pkg_name)
#   File "/usr/lib/python2.7/runpy.py", line 72, in _run_code
#     exec code in run_globals
#   File "/usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/usr/local/lib/python2.7/dist-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/usr/local/lib/python2.7/dist-packages/ipykernel/kernelapp.py", line 486, in start
#     self.io_loop.start()
#   File "/usr/local/lib/python2.7/dist-packages/tornado/ioloop.py", line 1008, in start
#     self._run_callback(self._callbacks.popleft())
#   File "/usr/local/lib/python2.7/dist-packages/tornado/ioloop.py", line 759, in _run_callback
#     ret = callback()
#   File "/usr/local/lib/python2.7/dist-packages/tornado/stack_context.py", line 276, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/usr/local/lib/python2.7/dist-packages/zmq/eventloop/zmqstream.py", line 536, in <lambda>
#     self.io_loop.add_callback(lambda : self._handle_events(self.socket, 0))
#   File "/usr/local/lib/python2.7/dist-packages/zmq/eventloop/zmqstream.py", line 450, in _handle_events
#     self._handle_recv()
#   File "/usr/local/lib/python2.7/dist-packages/zmq/eventloop/zmqstream.py", line 480, in _handle_recv
#     self._run_callback(callback, msg)
#   File "/usr/local/lib/python2.7/dist-packages/zmq/eventloop/zmqstream.py", line 432, in _run_callback
#     callback(*args, **kwargs)
#   File "/usr/local/lib/python2.7/dist-packages/tornado/stack_context.py", line 276, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/usr/local/lib/python2.7/dist-packages/ipykernel/kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "/usr/local/lib/python2.7/dist-packages/ipykernel/kernelbase.py", line 233, in dispatch_shell
#     handler(stream, idents, msg)
#   File "/usr/local/lib/python2.7/dist-packages/ipykernel/kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "/usr/local/lib/python2.7/dist-packages/ipykernel/ipkernel.py", line 208, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/usr/local/lib/python2.7/dist-packages/ipykernel/zmqshell.py", line 537, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/usr/local/lib/python2.7/dist-packages/IPython/core/interactiveshell.py", line 2714, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/usr/local/lib/python2.7/dist-packages/IPython/core/interactiveshell.py", line 2818, in run_ast_nodes
#     if self.run_code(code, result):
#   File "/usr/local/lib/python2.7/dist-packages/IPython/core/interactiveshell.py", line 2878, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-276-37c36c486561>", line 1, in <module>
#     saver = tf.train.Saver()
#   File "/usr/local/lib/python2.7/dist-packages/tensorflow/python/training/saver.py", line 1139, in __init__
#     self.build()
#   File "/usr/local/lib/python2.7/dist-packages/tensorflow/python/training/saver.py", line 1170, in build
#     restore_sequentially=self._restore_sequentially)
#   File "/usr/local/lib/python2.7/dist-packages/tensorflow/python/training/saver.py", line 691, in build
#     restore_sequentially, reshape)
#   File "/usr/local/lib/python2.7/dist-packages/tensorflow/python/training/saver.py", line 407, in _AddRestoreOps
#     tensors = self.restore_op(filename_tensor, saveable, preferred_shard)
#   File "/usr/local/lib/python2.7/dist-packages/tensorflow/python/training/saver.py", line 247, in restore_op
#     [spec.tensor.dtype])[0])
#   File "/usr/local/lib/python2.7/dist-packages/tensorflow/python/ops/gen_io_ops.py", line 640, in restore_v2
#     dtypes=dtypes, name=name)
#   File "/usr/local/lib/python2.7/dist-packages/tensorflow/python/framework/op_def_library.py", line 767, in apply_op
#     op_def=op_def)
#   File "/usr/local/lib/python2.7/dist-packages/tensorflow/python/framework/ops.py", line 2506, in create_op
#     original_op=self._default_original_op, op_def=op_def)
#   File "/usr/local/lib/python2.7/dist-packages/tensorflow/python/framework/ops.py", line 1269, in __init__
#     self._traceback = _extract_stack()
#
# NotFoundError (see above for traceback): Key beta1_power_15 not found in checkpoint
# 	 [[Node: save_8/RestoreV2_7 = RestoreV2[dtypes=[DT_FLOAT], _device="/job:localhost/replica:0/task:0/cpu:0"](_arg_save_8/Const_0_0, save_8/RestoreV2_7/tensor_names, save_8/RestoreV2_7/shape_and_slices)]]
#
# ('z_dim = ', 1)
# ('c_dim = ', 404)
# ('c_train = ', (2009, 404))
# Iter: 0
# Loss: 0.1748
# ('recon_loss = ', 0.17466596)
# ('saved session to ', '/home/vernwalrahul/projects/Workspace_halton_2d/checkpoints_z3_1l_more/model.ckpt')
# Iter: 1000
# Loss: 0.01129
# ('recon_loss = ', 0.010249531)
# ('saved session to ', '/home/vernwalrahul/projects/Workspace_halton_2d/checkpoints_z3_1l_more/model.ckpt')
# Iter: 2000
# Loss: 0.01036
# ('recon_loss = ', 0.009337816)
# ('saved session to ', '/home/vernwalrahul/projects/Workspace_halton_2d/checkpoints_z3_1l_more/model.ckpt')
# Iter: 3000
# Loss: 0.01037
# ('recon_loss = ', 0.009359594)
# ('saved session to ', '/home/vernwalrahul/projects/Workspace_halton_2d/checkpoints_z3_1l_more/model.ckpt')
# Iter: 4000
# Loss: 0.007386
# ('recon_loss = ', 0.0063899783)
# ('saved session to ', '/home/vernwalrahul/projects/Workspace_halton_2d/checkpoints_z3_1l_more/model.ckpt')
# Iter: 5000
# Loss: 0.007345
# ('recon_loss = ', 0.0063451338)
# ('saved session to ', '/home/vernwalrahul/projects/Workspace_halton_2d/checkpoints_z3_1l_more/model.ckpt')
# Iter: 6000
# Loss: 0.00787
# ('recon_loss = ', 0.0068759974)
# ('saved session to ', '/home/vernwalrahul/projects/Workspace_halton_2d/checkpoints_z3_1l_more/model.ckpt')
# Iter: 7000
# Loss: 0.005381
# ('recon_loss = ', 0.004349046)
# ('saved session to ', '/home/vernwalrahul/projects/Workspace_halton_2d/checkpoints_z3_1l_more/model.ckpt')
# Iter: 8000
# Loss: 0.005435
# ('recon_loss = ', 0.0044205394)
# ('saved session to ', '/home/vernwalrahul/projects/Workspace_halton_2d/checkpoints_z3_1l_more/model.ckpt')
# Iter: 9000
# Loss: 0.006416
# ('recon_loss = ', 0.0053508454)
# ('saved session to ', '/home/vernwalrahul/projects/Workspace_halton_2d/checkpoints_z3_1l_more/model.ckpt')
# Iter: 10000
# Loss: 0.005082
# ('recon_loss = ', 0.0040680096)
# ('saved session to ', '/home/vernwalrahul/projects/Workspace_halton_2d/checkpoints_z3_1l_more/model.ckpt')
# Iter: 11000
# Loss: 0.004044
# ('recon_loss = ', 0.0029842297)
# ('saved session to ', '/home/vernwalrahul/projects/Workspace_halton_2d/checkpoints_z3_1l_more/model.ckpt')
# Iter: 12000
# Loss: 0.004014
# ('recon_loss = ', 0.0029549873)
# ('saved session to ', '/home/vernwalrahul/projects/Workspace_halton_2d/checkpoints_z3_1l_more/model.ckpt')
# Iter: 13000
# Loss: 0.003906
# ('recon_loss = ', 0.002855805)
# ('saved session to ', '/home/vernwalrahul/projects/Workspace_halton_2d/checkpoints_z3_1l_more/model.ckpt')
# Iter: 14000
# Loss: 0.004343
# ('recon_loss = ', 0.0032947757)
# ('saved session to ', '/home/vernwalrahul/projects/Workspace_halton_2d/checkpoints_z3_1l_more/model.ckpt')
# Iter: 15000
# Loss: 0.003329
# ('recon_loss = ', 0.0022744043)
# ('saved session to ', '/home/vernwalrahul/projects/Workspace_halton_2d/checkpoints_z3_1l_more/model.ckpt')
# Iter: 16000
# Loss: 0.003781
# ('recon_loss = ', 0.0026885294)
# ('saved session to ', '/home/vernwalrahul/projects/Workspace_halton_2d/checkpoints_z3_1l_more/model.ckpt')
# Iter: 17000
# Loss: 0.002993
# ('recon_loss = ', 0.0019410299)
# ('saved session to ', '/home/vernwalrahul/projects/Workspace_halton_2d/checkpoints_z3_1l_more/model.ckpt')
# Iter: 18000
# Loss: 0.002729
# ('recon_loss = ', 0.0016427208)
# ('saved session to ', '/home/vernwalrahul/projects/Workspace_halton_2d/checkpoints_z3_1l_more/model.ckpt')
# Iter: 19000
# Loss: 0.002875
# ('recon_loss = ', 0.0018038934)
# ('saved session to ', '/home/vernwalrahul/projects/Workspace_halton_2d/checkpoints_z3_1l_more/model.ckpt')
# Iter: 20000
# Loss: 0.002893
# ('recon_loss = ', 0.0018512585)
# ('saved session to ', '/home/vernwalrahul/projects/Workspace_halton_2d/checkpoints_z3_1l_more/model.ckpt')
# Iter: 21000
# Loss: 0.002444
# ('recon_loss = ', 0.0013586115)
# ('saved session to ', '/home/vernwalrahul/projects/Workspace_halton_2d/checkpoints_z3_1l_more/model.ckpt')
# Iter: 22000
# Loss: 0.002695
# ('recon_loss = ', 0.0016240638)
# ('saved session to ', '/home/vernwalrahul/projects/Workspace_halton_2d/checkpoints_z3_1l_more/model.ckpt')
# Iter: 23000
# Loss: 0.002421
# ('recon_loss = ', 0.001363428)
# ('saved session to ', '/home/vernwalrahul/projects/Workspace_halton_2d/checkpoints_z3_1l_more/model.ckpt')
# Iter: 24000
# Loss: 0.00245
# ('recon_loss = ', 0.001398086)
# ('saved session to ', '/home/vernwalrahul/projects/Workspace_halton_2d/checkpoints_z3_1l_more/model.ckpt')
# Iter: 25000
# Loss: 0.001961
# ('recon_loss = ', 0.0008868965)
# ('saved session to ', '/home/vernwalrahul/projects/Workspace_halton_2d/checkpoints_z3_1l_more/model.ckpt')
# Iter: 26000
# Loss: 0.002167
# ('recon_loss = ', 0.0010860475)
# ('saved session to ', '/home/vernwalrahul/projects/Workspace_halton_2d/checkpoints_z3_1l_more/model.ckpt')
# Iter: 27000
# Loss: 0.002457
# ('recon_loss = ', 0.0014182226)
# ('saved session to ', '/home/vernwalrahul/projects/Workspace_halton_2d/checkpoints_z3_1l_more/model.ckpt')
# Iter: 28000
# Loss: 0.002421
# ('recon_loss = ', 0.0014064295)
# ('saved session to ', '/home/vernwalrahul/projects/Workspace_halton_2d/checkpoints_z3_1l_more/model.ckpt')
# Iter: 29000
# Loss: 0.002222
# ('recon_loss = ', 0.0011720167)
# ('saved session to ', '/home/vernwalrahul/projects/Workspace_halton_2d/checkpoints_z3_1l_more/model.ckpt')
# Iter: 30000
# Loss: 0.001989
# ('recon_loss = ', 0.0009294156)
# ('saved session to ', '/home/vernwalrahul/projects/Workspace_halton_2d/checkpoints_z3_1l_more/model.ckpt')
# Iter: 31000
# Loss: 0.001841
# ('recon_loss = ', 0.0008065437)
# ('saved session to ', '/home/vernwalrahul/projects/Workspace_halton_2d/checkpoints_z3_1l_more/model.ckpt')
# Iter: 32000
# Loss: 0.002016
# ('recon_loss = ', 0.0009557998)
# ('saved session to ', '/home/vernwalrahul/projects/Workspace_halton_2d/checkpoints_z3_1l_more/model.ckpt')
# Iter: 33000
# Loss: 0.002184
# ('recon_loss = ', 0.001177408)
# ('saved session to ', '/home/vernwalrahul/projects/Workspace_halton_2d/checkpoints_z3_1l_more/model.ckpt')
# Iter: 34000
# Loss: 0.001772
# ('recon_loss = ', 0.0006937763)
# ('saved session to ', '/home/vernwalrahul/projects/Workspace_halton_2d/checkpoints_z3_1l_more/model.ckpt')
# Iter: 35000
# Loss: 0.001864
# ('recon_loss = ', 0.0008519748)
# ('saved session to ', '/home/vernwalrahul/projects/Workspace_halton_2d/checkpoints_z3_1l_more/model.ckpt')
# Iter: 36000
# Loss: 0.002004
# ('recon_loss = ', 0.0009581349)
# ('saved session to ', '/home/vernwalrahul/projects/Workspace_halton_2d/checkpoints_z3_1l_more/model.ckpt')
# Iter: 37000
# Loss: 0.001718
# ('recon_loss = ', 0.0006457512)
# ('saved session to ', '/home/vernwalrahul/projects/Workspace_halton_2d/checkpoints_z3_1l_more/model.ckpt')
# Iter: 38000
# Loss: 0.002213
# ('recon_loss = ', 0.0012064787)
# ('saved session to ', '/home/vernwalrahul/projects/Workspace_halton_2d/checkpoints_z3_1l_more/model.ckpt')
# Iter: 39000
# Loss: 0.001748
# ('recon_loss = ', 0.00072748796)
# ('saved session to ', '/home/vernwalrahul/projects/Workspace_halton_2d/checkpoints_z3_1l_more/model.ckpt')
# Iter: 40000
# Loss: 0.001809
# ('recon_loss = ', 0.0007914387)
# ('saved session to ', '/home/vernwalrahul/projects/Workspace_halton_2d/checkpoints_z3_1l_more/model.ckpt')
# Iter: 41000
# Loss: 0.001744
# ('recon_loss = ', 0.00072123826)
# ('saved session to ', '/home/vernwalrahul/projects/Workspace_halton_2d/checkpoints_z3_1l_more/model.ckpt')
# Iter: 42000
# Loss: 0.001836
# ('recon_loss = ', 0.0008176416)
# ('saved session to ', '/home/vernwalrahul/projects/Workspace_halton_2d/checkpoints_z3_1l_more/model.ckpt')
# Iter: 43000
# Loss: 0.001571
# ('recon_loss = ', 0.0005699358)
# ('saved session to ', '/home/vernwalrahul/projects/Workspace_halton_2d/checkpoints_z3_1l_more/model.ckpt')
# Iter: 44000
# Loss: 0.002214
# ('recon_loss = ', 0.0011376133)
# ('saved session to ', '/home/vernwalrahul/projects/Workspace_halton_2d/checkpoints_z3_1l_more/model.ckpt')
# Iter: 45000
# Loss: 0.001844
# ('recon_loss = ', 0.0008511394)
# ('saved session to ', '/home/vernwalrahul/projects/Workspace_halton_2d/checkpoints_z3_1l_more/model.ckpt')
# Iter: 46000
# Loss: 0.001621
# ('recon_loss = ', 0.00061947224)
# ('saved session to ', '/home/vernwalrahul/projects/Workspace_halton_2d/checkpoints_z3_1l_more/model.ckpt')
# Iter: 47000
# Loss: 0.001629
# ('recon_loss = ', 0.00059991673)
# ('saved session to ', '/home/vernwalrahul/projects/Workspace_halton_2d/checkpoints_z3_1l_more/model.ckpt')
# Iter: 48000
# Loss: 0.001801
# ('recon_loss = ', 0.0007658986)
# ('saved session to ', '/home/vernwalrahul/projects/Workspace_halton_2d/checkpoints_z3_1l_more/model.ckpt')
# Iter: 49000
# Loss: 0.001551
# ('recon_loss = ', 0.00058234175)
# ('saved session to ', '/home/vernwalrahul/projects/Workspace_halton_2d/checkpoints_z3_1l_more/model.ckpt')
# Iter: 50000
# Loss: 0.001523
# ('recon_loss = ', 0.0005274239)
# ('saved session to ', '/home/vernwalrahul/projects/Workspace_halton_2d/checkpoints_z3_1l_more/model.ckpt')
# Iter: 51000
# Loss: 0.001594
# ('recon_loss = ', 0.000598801)
# ('saved session to ', '/home/vernwalrahul/projects/Workspace_halton_2d/checkpoints_z3_1l_more/model.ckpt')
# Iter: 52000
# Loss: 0.001733
# ('recon_loss = ', 0.0007057844)
# ('saved session to ', '/home/vernwalrahul/projects/Workspace_halton_2d/checkpoints_z3_1l_more/model.ckpt')
# Iter: 53000
# Loss: 0.001547
# ('recon_loss = ', 0.00054118095)
# ('saved session to ', '/home/vernwalrahul/projects/Workspace_halton_2d/checkpoints_z3_1l_more/model.ckpt')
# Iter: 54000
# Loss: 0.001519
# ('recon_loss = ', 0.0005049871)
# ('saved session to ', '/home/vernwalrahul/projects/Workspace_halton_2d/checkpoints_z3_1l_more/model.ckpt')
# Iter: 55000
# Loss: 0.001892
# ('recon_loss = ', 0.0008829393)
# ('saved session to ', '/home/vernwalrahul/projects/Workspace_halton_2d/checkpoints_z3_1l_more/model.ckpt')
# Iter: 56000
# Loss: 0.001466
# ('recon_loss = ', 0.00050248613)
# ('saved session to ', '/home/vernwalrahul/projects/Workspace_halton_2d/checkpoints_z3_1l_more/model.ckpt')
# Iter: 57000
# Loss: 0.001496
# ('recon_loss = ', 0.000520721)
# ('saved session to ', '/home/vernwalrahul/projects/Workspace_halton_2d/checkpoints_z3_1l_more/model.ckpt')
# Iter: 58000
# Loss: 0.001959
# ('recon_loss = ', 0.00097367953)
# ('saved session to ', '/home/vernwalrahul/projects/Workspace_halton_2d/checkpoints_z3_1l_more/model.ckpt')
# Iter: 59000
# Loss: 0.001457
# ('recon_loss = ', 0.00045494686)
# ('saved session to ', '/home/vernwalrahul/projects/Workspace_halton_2d/checkpoints_z3_1l_more/model.ckpt')
# Iter: 60000
# Loss: 0.001456
# ('recon_loss = ', 0.0005010858)
# ('saved session to ', '/home/vernwalrahul/projects/Workspace_halton_2d/checkpoints_z3_1l_more/model.ckpt')
# Iter: 61000
# Loss: 0.001531
# ('recon_loss = ', 0.0005439285)
# ('saved session to ', '/home/vernwalrahul/projects/Workspace_halton_2d/checkpoints_z3_1l_more/model.ckpt')
# Iter: 62000
# Loss: 0.001347
# ('recon_loss = ', 0.00039339694)
# ('saved session to ', '/home/vernwalrahul/projects/Workspace_halton_2d/checkpoints_z3_1l_more/model.ckpt')
# Iter: 63000
# Loss: 0.001394
# ('recon_loss = ', 0.0004379614)
# ('saved session to ', '/home/vernwalrahul/projects/Workspace_halton_2d/checkpoints_z3_1l_more/model.ckpt')
# Iter: 64000
# Loss: 0.001411
# ('recon_loss = ', 0.00048298817)
# ('saved session to ', '/home/vernwalrahul/projects/Workspace_halton_2d/checkpoints_z3_1l_more/model.ckpt')
# Iter: 65000
# Loss: 0.001513
# ('recon_loss = ', 0.000564706)
# ('saved session to ', '/home/vernwalrahul/projects/Workspace_halton_2d/checkpoints_z3_1l_more/model.ckpt')
# Iter: 66000
# Loss: 0.001565
# ('recon_loss = ', 0.00058230676)
# ('saved session to ', '/home/vernwalrahul/projects/Workspace_halton_2d/checkpoints_z3_1l_more/model.ckpt')
# Iter: 67000
# Loss: 0.001409
# ('recon_loss = ', 0.00043615157)
# ('saved session to ', '/home/vernwalrahul/projects/Workspace_halton_2d/checkpoints_z3_1l_more/model.ckpt')
# Iter: 68000
# Loss: 0.001405
# ('recon_loss = ', 0.00047270843)
# ('saved session to ', '/home/vernwalrahul/projects/Workspace_halton_2d/checkpoints_z3_1l_more/model.ckpt')
# Iter: 69000
# Loss: 0.001452
# ('recon_loss = ', 0.00050806394)
# ('saved session to ', '/home/vernwalrahul/projects/Workspace_halton_2d/checkpoints_z3_1l_more/model.ckpt')
# Iter: 70000
# Loss: 0.001293
# ('recon_loss = ', 0.0003644136)
# ('saved session to ', '/home/vernwalrahul/projects/Workspace_halton_2d/checkpoints_z3_1l_more/model.ckpt')
# Iter: 71000
# Loss: 0.001335
# ('recon_loss = ', 0.0003891163)
# ('saved session to ', '/home/vernwalrahul/projects/Workspace_halton_2d/checkpoints_z3_1l_more/model.ckpt')
# Iter: 72000
# Loss: 0.001439
# ('recon_loss = ', 0.00049100677)
# ('saved session to ', '/home/vernwalrahul/projects/Workspace_halton_2d/checkpoints_z3_1l_more/model.ckpt')
# Iter: 73000
# Loss: 0.001488
# ('recon_loss = ', 0.00055045274)
# ('saved session to ', '/home/vernwalrahul/projects/Workspace_halton_2d/checkpoints_z3_1l_more/model.ckpt')
# Iter: 74000
# Loss: 0.001367
# ('recon_loss = ', 0.00044449864)
# ('saved session to ', '/home/vernwalrahul/projects/Workspace_halton_2d/checkpoints_z3_1l_more/model.ckpt')
# Iter: 75000
# Loss: 0.00146
# ('recon_loss = ', 0.00056648406)
# ('saved session to ', '/home/vernwalrahul/projects/Workspace_halton_2d/checkpoints_z3_1l_more/model.ckpt')
# Iter: 76000
# Loss: 0.001261
# ('recon_loss = ', 0.00035217014)
# ('saved session to ', '/home/vernwalrahul/projects/Workspace_halton_2d/checkpoints_z3_1l_more/model.ckpt')
# Iter: 77000
# Loss: 0.001321
# ('recon_loss = ', 0.00038347766)
# ('saved session to ', '/home/vernwalrahul/projects/Workspace_halton_2d/checkpoints_z3_1l_more/model.ckpt')
# Iter: 78000
# Loss: 0.001234
# ('recon_loss = ', 0.00034439086)
# ('saved session to ', '/home/vernwalrahul/projects/Workspace_halton_2d/checkpoints_z3_1l_more/model.ckpt')
# Iter: 79000
# Loss: 0.001439
# ('recon_loss = ', 0.00050860323)
# ('saved session to ', '/home/vernwalrahul/projects/Workspace_halton_2d/checkpoints_z3_1l_more/model.ckpt')
# Iter: 80000
# Loss: 0.001306
# ('recon_loss = ', 0.00042750887)
# ('saved session to ', '/home/vernwalrahul/projects/Workspace_halton_2d/checkpoints_z3_1l_more/model.ckpt')
# Iter: 81000
# Loss: 0.001247
# ('recon_loss = ', 0.00032000063)
# ('saved session to ', '/home/vernwalrahul/projects/Workspace_halton_2d/checkpoints_z3_1l_more/model.ckpt')
# Iter: 82000
# Loss: 0.001392
# ('recon_loss = ', 0.00047066138)
# ('saved session to ', '/home/vernwalrahul/projects/Workspace_halton_2d/checkpoints_z3_1l_more/model.ckpt')
# Iter: 83000
# Loss: 0.001315
# ('recon_loss = ', 0.0004041601)
# ('saved session to ', '/home/vernwalrahul/projects/Workspace_halton_2d/checkpoints_z3_1l_more/model.ckpt')
# Iter: 84000
# Loss: 0.00145
# ('recon_loss = ', 0.0005375778)
# ('saved session to ', '/home/vernwalrahul/projects/Workspace_halton_2d/checkpoints_z3_1l_more/model.ckpt')
# Iter: 85000
# Loss: 0.001536
# ('recon_loss = ', 0.00063094776)
# ('saved session to ', '/home/vernwalrahul/projects/Workspace_halton_2d/checkpoints_z3_1l_more/model.ckpt')
# Iter: 86000
# Loss: 0.001347
# ('recon_loss = ', 0.00044048962)
# ('saved session to ', '/home/vernwalrahul/projects/Workspace_halton_2d/checkpoints_z3_1l_more/model.ckpt')
# Iter: 87000
# Loss: 0.00127
# ('recon_loss = ', 0.00038205384)
# ('saved session to ', '/home/vernwalrahul/projects/Workspace_halton_2d/checkpoints_z3_1l_more/model.ckpt')
# Iter: 88000
# Loss: 0.001271
# ('recon_loss = ', 0.00039529603)
# ('saved session to ', '/home/vernwalrahul/projects/Workspace_halton_2d/checkpoints_z3_1l_more/model.ckpt')
# Iter: 89000
# Loss: 0.001277
# ('recon_loss = ', 0.00039586634)
# ('saved session to ', '/home/vernwalrahul/projects/Workspace_halton_2d/checkpoints_z3_1l_more/model.ckpt')
# Iter: 90000
# Loss: 0.001275
# ('recon_loss = ', 0.00038384728)
# ('saved session to ', '/home/vernwalrahul/projects/Workspace_halton_2d/checkpoints_z3_1l_more/model.ckpt')
# Iter: 91000
# Loss: 0.001347
# ('recon_loss = ', 0.00044475516)
# ('saved session to ', '/home/vernwalrahul/projects/Workspace_halton_2d/checkpoints_z3_1l_more/model.ckpt')
# Iter: 92000
# Loss: 0.001238
# ('recon_loss = ', 0.0003497742)
# ('saved session to ', '/home/vernwalrahul/projects/Workspace_halton_2d/checkpoints_z3_1l_more/model.ckpt')
# Iter: 93000
# Loss: 0.00121
# ('recon_loss = ', 0.0003262373)
# ('saved session to ', '/home/vernwalrahul/projects/Workspace_halton_2d/checkpoints_z3_1l_more/model.ckpt')
# Iter: 94000
# Loss: 0.001328
# ('recon_loss = ', 0.00044779168)
# ('saved session to ', '/home/vernwalrahul/projects/Workspace_halton_2d/checkpoints_z3_1l_more/model.ckpt')
# Iter: 95000
# Loss: 0.001339
# ('recon_loss = ', 0.00048381623)
# ('saved session to ', '/home/vernwalrahul/projects/Workspace_halton_2d/checkpoints_z3_1l_more/model.ckpt')
# Iter: 96000
# Loss: 0.001248
# ('recon_loss = ', 0.00034219134)
# ('saved session to ', '/home/vernwalrahul/projects/Workspace_halton_2d/checkpoints_z3_1l_more/model.ckpt')
# Iter: 97000
# Loss: 0.001318
# ('recon_loss = ', 0.0004250064)
# ('saved session to ', '/home/vernwalrahul/projects/Workspace_halton_2d/checkpoints_z3_1l_more/model.ckpt')
# Iter: 98000
# Loss: 0.001348
# ('recon_loss = ', 0.0005034766)
# ('saved session to ', '/home/vernwalrahul/projects/Workspace_halton_2d/checkpoints_z3_1l_more/model.ckpt')
# Iter: 99000
# Loss: 0.001258
# ('recon_loss = ', 0.00037016792)
# ('saved session to ', '/home/vernwalrahul/projects/Workspace_halton_2d/checkpoints_z3_1l_more/model.ckpt')
# Iter: 100000
# Loss: 0.001197
# ('recon_loss = ', 0.0003634469)
# ('saved session to ', '/home/vernwalrahul/projects/Workspace_halton_2d/checkpoints_z3_1l_more/model.ckpt')
# Iter: 101000
# Loss: 0.001129
# ('recon_loss = ', 0.0003107735)
# ('saved session to ', '/home/vernwalrahul/projects/Workspace_halton_2d/checkpoints_z3_1l_more/model.ckpt')
# Iter: 102000
# Loss: 0.001131
# ('recon_loss = ', 0.00028394905)
# ('saved session to ', '/home/vernwalrahul/projects/Workspace_halton_2d/checkpoints_z3_1l_more/model.ckpt')
# Iter: 103000
# Loss: 0.001345
# ('recon_loss = ', 0.00050960743)
# ('saved session to ', '/home/vernwalrahul/projects/Workspace_halton_2d/checkpoints_z3_1l_more/model.ckpt')
# Iter: 104000
# Loss: 0.001284
# ('recon_loss = ', 0.00045963988)
# ('saved session to ', '/home/vernwalrahul/projects/Workspace_halton_2d/checkpoints_z3_1l_more/model.ckpt')
# Iter: 105000
# Loss: 0.001436
# ('recon_loss = ', 0.00058148033)
# ('saved session to ', '/home/vernwalrahul/projects/Workspace_halton_2d/checkpoints_z3_1l_more/model.ckpt')
# Iter: 106000
# Loss: 0.001189
# ('recon_loss = ', 0.00035812438)
# ('saved session to ', '/home/vernwalrahul/projects/Workspace_halton_2d/checkpoints_z3_1l_more/model.ckpt')
# Iter: 107000
# Loss: 0.001137
# ('recon_loss = ', 0.00031806563)
# ('saved session to ', '/home/vernwalrahul/projects/Workspace_halton_2d/checkpoints_z3_1l_more/model.ckpt')
# Iter: 108000
# Loss: 0.00124
# ('recon_loss = ', 0.00036782742)
# ('saved session to ', '/home/vernwalrahul/projects/Workspace_halton_2d/checkpoints_z3_1l_more/model.ckpt')
# Iter: 109000
# Loss: 0.001229
# ('recon_loss = ', 0.00037646428)
# ('saved session to ', '/home/vernwalrahul/projects/Workspace_halton_2d/checkpoints_z3_1l_more/model.ckpt')
# Iter: 110000
# Loss: 0.001223
# ('recon_loss = ', 0.00038051227)
# ('saved session to ', '/home/vernwalrahul/projects/Workspace_halton_2d/checkpoints_z3_1l_more/model.ckpt')
# Iter: 111000
# Loss: 0.00143
# ('recon_loss = ', 0.00059765985)
# ('saved session to ', '/home/vernwalrahul/projects/Workspace_halton_2d/checkpoints_z3_1l_more/model.ckpt')
# Iter: 112000
# Loss: 0.001209
# ('recon_loss = ', 0.0003889735)
# ('saved session to ', '/home/vernwalrahul/projects/Workspace_halton_2d/checkpoints_z3_1l_more/model.ckpt')
# Iter: 113000
# Loss: 0.001381
# ('recon_loss = ', 0.0005355818)
# ('saved session to ', '/home/vernwalrahul/projects/Workspace_halton_2d/checkpoints_z3_1l_more/model.ckpt')
# Iter: 114000
# Loss: 0.001304
# ('recon_loss = ', 0.00047190767)
# ('saved session to ', '/home/vernwalrahul/projects/Workspace_halton_2d/checkpoints_z3_1l_more/model.ckpt')
# Iter: 115000
# Loss: 0.00123
# ('recon_loss = ', 0.00039995307)
# ('saved session to ', '/home/vernwalrahul/projects/Workspace_halton_2d/checkpoints_z3_1l_more/model.ckpt')
# Iter: 116000
# Loss: 0.001096
# ('recon_loss = ', 0.00029238203)
# ('saved session to ', '/home/vernwalrahul/projects/Workspace_halton_2d/checkpoints_z3_1l_more/model.ckpt')
# Iter: 117000
# Loss: 0.001198
# ('recon_loss = ', 0.0003722883)
# ('saved session to ', '/home/vernwalrahul/projects/Workspace_halton_2d/checkpoints_z3_1l_more/model.ckpt')
# Iter: 118000
# Loss: 0.001227
# ('recon_loss = ', 0.00038290056)
# ('saved session to ', '/home/vernwalrahul/projects/Workspace_halton_2d/checkpoints_z3_1l_more/model.ckpt')
# Iter: 119000
# Loss: 0.001132
# ('recon_loss = ', 0.00032012168)
# ('saved session to ', '/home/vernwalrahul/projects/Workspace_halton_2d/checkpoints_z3_1l_more/model.ckpt')

# %%
print("z_dim = ",z_dim)
# Out:
# ('z_dim = ', 1)

# %%
# plot the latent space
num_viz = 50
print("c_test.shape = ",c_test.shape)
# print(c_test[:,:4])
vizIdx = randint(0,numTrain-1);
# vizIdx = 2000
print vizIdx
c_sample_seed = c_train[vizIdx,:]
occ_g = c_train[vizIdx,4:].reshape(20,20)
ts = X_train[vizIdx,:2]
print("Training Sample = ", ts)
# print(c_sample_seed[:4])
init = c_sample_seed[:2]
goal = c_sample_seed[2:4]
c_sample = np.repeat([c_sample_seed],num_viz,axis=0)

print("c_sample.shape = ",c_sample.shape)
# directly sample from the latent space (preferred, what we will use in the end)
y_viz, z_viz = sess.run([y, z], feed_dict={z: np.random.randn(num_viz, z_dim), c: c_sample})

fig1 = plt.figure(figsize=(10,6), dpi=80)
ax1 = fig1.add_subplot(111, aspect='equal')

plt.scatter(y_viz[:,1],y_viz[:,0], color="green", s=20)

print("output_sample = ", y_viz[:5,:2])

for i in range(20):
        for j in range(20):
            if(occ_g[i,j]==0):
                ax1.add_patch(patches.Rectangle(
                (j/20.0, i/20.0),   # (x,y)
                0.05,          # width
                0.05,          # height
                alpha=0.6
                ))

plt.scatter(init[1], init[0], color="red", s=100, edgecolors='black') # init
plt.scatter(goal[1], goal[0], color="blue", s=100, edgecolors='black') # goal
plt.scatter(ts[1], ts[0], color="orange", s=80, edgecolors='black') 

plt.xlim(0,1)
plt.ylim(0,1)

# plt.savefig("output_"+str(vizIdx)+".jpg", bbox_inches='tight')
plt.show()
# Out:
# ('c_test.shape = ', (5023, 404))
# 243
# ('Training Sample = ', array([0.34178266, 0.70128207]))
# ('c_sample.shape = ', (50, 404))
# ('output_sample = ', array([[0.74814045, 0.41798252],
#        [0.4046348 , 0.7481547 ],
#        [0.3196704 , 0.7059267 ],
#        [0.35502753, 0.65478927],
#        [0.7493417 , 0.42044514]], dtype=float32))
